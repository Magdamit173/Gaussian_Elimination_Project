# %%
import random 
import math 
import matplotlib.pyplot as plt
import pprint 

# notation i_ means index of
# notation l_ means local of
# I am using row-major

A = [
    [1, 1, 1, 1],
    [2, -1, 3, 2],
    [3, 2, 1, -1],
    [1, 4, -2, 1],
]

# swaps on row
B = [10, 20, 5, 0] # represented as [n x 1] e.g. [5 x 1]

# swaps on column
C = [f"X{n}" for n in range(1, dimension+1)] # represented as [1 x n] e.g. [1 x 5]


class Gauss(): 
    def __init__(self): 
        self.found_max = None
        self.found_row = None 
        self.found_column = None

    def print(self, *matrices): 
        # will fix or never XD
        for matrix in matrices: 
            print("[") 
            for iterator in matrix:
                print("\t", iterator)
            print("]")

    def dimension_1D(self, matrix): 
        # returns dimension if row and column are equal shape
        # returns -1 if dimension does not match
        
        row_size = len(matrix)
        column_size = [] 

        for row in matrix: 
            column_size.append(len(row))

        return row_size if row_size == sum(column_size) / row_size else -1
            
    def swap_element(self, vector, index_A, index_B): 
        cache_A = vector[index_A]
        cache_B = vector[index_B]

        vector[index_A] = cache_B 
        vector[index_B] = cache_A

        return vector

    def swap_row(self, matrixA, matrixB, index_A, index_B):
        cache_A = tuple(matrixA[index_A])
        cache_B = tuple(matrixA[index_B])

        for (iterator, real) in enumerate(cache_A): 
            matrixA[index_B][iterator] = real
        for (iterator, real) in enumerate(cache_B): 
            matrixA[index_A][iterator] = real

        matrixB = self.swap_element(matrixB, index_A, index_B)

        return [matrixA, matrixB]

    def swap_column(self, matrixA, matrixC, index_A, index_B): 
        cache_A = tuple([matrixA[iterator][index_A] for iterator in range(len(matrixA))])
        cache_B = tuple([matrixA[iterator][index_B] for iterator in range(len(matrixA))])

        for (iterator, real) in enumerate(cache_A): 
            matrixA[iterator][index_B] = real
        for (iterator, real) in enumerate(cache_B): 
            matrixA[iterator][index_A] = real

        
        matrixC = self.swap_element(matrixC, index_A, index_B)
            
        return [matrixA, matrixC]
    
    def update_found(self, matrix, found_max, found_row,found_column): 
        self.found_max = found_max
        self.found_row = found_row 
        self.found_column = found_column

        # the findings will return at gauss object itself 
        
    def obtain_max(self, matrix):    
        self.found_max = None
        self.found_row = None 
        self.found_column = None

        for (i_row, row) in enumerate(matrix):
            
            if i_row == 0 or self.found_max == None: 
                
                self.update_found(matrix, max(row), i_row, row.index(max(row)))
                continue 
                       
            elif max(row) > self.found_max: 
                self.update_found(matrix, max(row), i_row, row.index(max(row)))    

        # the findings will return at gauss object itself 
   

    def sample_matrix(self, matrix, begin_row = 0, begin_column = 0, end_row = 0, end_column = 0): 
        # scrap or optional XD
        cache_matrix = []
        
        row_length = len(matrix)
        column_length = len(matrix[row_length-1])
        
        #### reinitialize to the parameters ####
        if end_row == 0: 
            end_row = row_length - 1
        if end_column == 0:
            end_column = column_length - 1
        ########################################

        for (i_row, real) in enumerate(matrix):
            row = matrix[i_row]
            if (i_row >= begin_row) and (i_row <= end_row): 
                cache_matrix.append(row[begin_column:end_column+1]) 

        return cache_matrix     

    def paste_matrix(self, original_matrix, sampled_matrix, begin_row = 0, begin_column = 0, end_row = 0, end_column = 0):
        # scrap or optional XD
        cache_matrix = []
        
        row_length = len(original_matrix)
        column_length = len(original_matrix[row_length-1])

        sample_row_length = len(sampled_matrix)
        sample_column_length = len(sampled_matrix[sample_row_length-1])
        
        #### reinitialize to the parameters ####
        if end_row == 0: 
            end_row = row_length - 1
        if end_column == 0:
            end_column = column_length - 1
        ########################################

        for (original_row_index, original_row) in enumerate(original_matrix): 
            
            sanitize_row = original_row_index + begin_row 
            if sanitize_row < end_row:  
                for (original_column_index, original_column) in enumerate(original_row):
                    sanitize_column = original_column_index + begin_column

                    if sanitize_column < end_column:
                            
                        # print(sanitize_row, sanitize_column, "|",  original_row_index, original_column_index, sampled_matrix)
                        try: 
                            # will fix it later or never XD
                            original_matrix[sanitize_row][sanitize_column] = sampled_matrix[original_row_index][original_column_index] 
                        except: 
                            pass
                    else: 
                        continue
            else: 
                continue

        return original_matrix

        
    def row_pivot_normalize(self, matrixA, matrixB, begin_row = 0, begin_column = 0): 
        array = matrixA[begin_row][begin_column:]
        for (i_column, column) in enumerate(array):
            matrixA[begin_row][i_column + begin_column] = column/array[begin_row]

            if i_column == begin_row:
                # just to run once
                matrixB[begin_row] = matrixB[begin_row]/array[begin_row]

        return [matrixA, matrixB]

    def column_pivot_zero(self, matrixA, matrixB, begin_row = 0, begin_column = 0):
        # to make it same size #
        begin_column = begin_row
        ########################
        
        pivot = 1
        for (row_index, row) in enumerate(matrixA): 
            
            pivot_cache = None 
            column_cache = None
            
            if row_index <= begin_row: 
                continue 

            for (column_index, column) in enumerate(row): 
                
                if column_index < begin_column: 
                    continue 
                    
                
                if column_index  == begin_column:
                    pivot_cache = matrixA[begin_row][begin_column] # R1
                    column_cache = column #R2
                    # just to run once
                    matrixBElement = (column_cache * matrixB[begin_row]) - (pivot_cache * matrixB[row_index])
                    matrixB[row_index] = matrixBElement
                    
                    
                matrixAElement = (column_cache * matrixA[begin_row][column_index]) - (pivot_cache * column)
                matrixA[row_index][column_index] = matrixAElement

                                

        return [matrixA, matrixB]

    def back_substitution(self, matrixA, matrixB):
        local_dimension = self.dimension_1D(matrixA) - 1
        cache_total = 0
        for iterator in range(local_dimension, -1,  -1): 
            current_total = (matrixB[iterator] - cache_total) / matrixA[iterator][iterator]
            print(current_total, iterator)
            

gauss = Gauss()
dimension = gauss.dimension_1D(A) 
for (i_row, row) in enumerate(A): 

    if i_row == dimension - 1: 
        continue
        
    if dimension == -1: 
        break
    
    print(f"######## Attempt: {i_row} ########")


    gauss.print(A)
    gauss.obtain_max(A) 

    swap_row = gauss.swap_row(A, B, i_row, gauss.found_row)
    A = swap_row[0]
    B = swap_row[1]

    swap_column = gauss.swap_column(A, C, i_row, gauss.found_column)
    A = swap_column[0]
    C = swap_column[1]

    row_pivot_normalize = gauss.row_pivot_normalize(A, B, i_row)

    A = row_pivot_normalize[0]
    B = row_pivot_normalize[1]

    column_pivot_zero = gauss.column_pivot_zero(A, B, i_row)

    A = column_pivot_zero[0]
    B = column_pivot_zero[1]
    
    gauss.print(A, B, C)


gauss.back_substitution(A, B)
# Out:
# ######## Attempt: 0 ########
# [
# 	 [1, 1, 1, 1]
# 	 [2, -1, 3, 2]
# 	 [3, 2, 1, -1]
# 	 [1, 4, -2, 1]
# ]
# [
# 	 [1.0, 0.25, -0.5, 0.25]
# 	 [0.0, 2.25, 2.5, 2.25]
# 	 [0.0, 2.5, 2.0, -1.5]
# 	 [0.0, 0.75, 1.5, 0.75]
# ]
# [
# 	 0.0
# 	 20.0
# 	 5.0
# 	 10.0
# ]
# [
# 	 X2
# 	 X1
# 	 X3
# 	 X4
# ]
# ######## Attempt: 1 ########
# [
# 	 [1.0, 0.25, -0.5, 0.25]
# 	 [0.0, 2.25, 2.5, 2.25]
# 	 [0.0, 2.5, 2.0, -1.5]
# 	 [0.0, 0.75, 1.5, 0.75]
# ]
# [
# 	 [1.0, 0.0, 0.7, 0.7]
# 	 [0.0, 1.0, 0.9, 0.9]
# 	 [0.0, 0.0, 0.7, -3.3]
# 	 [0.0, 0.0, -0.6000000000000001, -0.6000000000000001]
# ]
# [
# 	 4.0
# 	 8.0
# 	 -11.0
# 	 -2.0
# ]
# [
# 	 X2
# 	 X3
# 	 X1
# 	 X4
# ]
# ######## Attempt: 2 ########
# [
# 	 [1.0, 0.0, 0.7, 0.7]
# 	 [0.0, 1.0, 0.9, 0.9]
# 	 [0.0, 0.0, 0.7, -3.3]
# 	 [0.0, 0.0, -0.6000000000000001, -0.6000000000000001]
# ]
# [
# 	 [0.7, 0.0, 0.0, -3.3]
# 	 [0.9, 1.0, 0.0, 0.9]
# 	 [0.7, 0.0, 1.0, 0.7]
# 	 [-0.6000000000000001, 0.0, 0.0, -0.6000000000000001]
# ]
# [
# 	 -11.0
# ...

# %%
import random 
import math 
import matplotlib.pyplot as plt
import pprint 

# notation i_ means index of
# notation l_ means local of

A = [
    [0, 4, 3, 6, 8], 
    [4, 6, 9, 1, 3], 
    [3, 4, 7, 8, 9],
    [4, 7, 3, 1, 3], 
    [1, 5, 8, 1, 5]
]

B = [
    [0, 4, 3, 6, 8] # will implement flatten, will used recursion i guess?.  i did it before but will do it some time
]

class Gauss(): 
    def __init__(self): 
        self.matrix_A = []
        self.matrix_B = []

    def set_A(self, matrix_A): 
       self.matrix_A = matrix_A

    def get_A(self): 
        return self.matrix_A
        
    def set_B(self, matrix_B):
        self.matrix_B = matrix_B

    def get_B(self): 
        return self.matrix_B

    def swap_row(self, index_A, index_B):
        cache_A = tuple(self.matrix_A[index_A])
        cache_B = tuple(self.matrix_A[index_B])

        for (iterator, real) in enumerate(cache_A): 
            self.matrix_A[index_B][iterator] = real
        for (iterator, real) in enumerate(cache_B): 
            self.matrix_A[index_A][iterator] = real

    def swap_column(self, index_A, index_B): 
        cache_A = tuple([self.matrix_A[iterator][index_A] for iterator in range(len(self.matrix_A)) ])
        cache_B = tuple([self.matrix_A[iterator][index_B] for iterator in range(len(self.matrix_A)) ])

        for (iterator, real) in enumerate(cache_A): 
            self.matrix_A[iterator][index_B] = real
        for (iterator, real) in enumerate(cache_B): 
            self.matrix_A[iterator][index_A] = real

    def sample_matrix(self, matrix, begin_row = 0, begin_column = 0, end_row = 0, end_column = 0): 
        cache_matrix = []
        
        row_length = len(matrix)
        column_length = len(matrix[row_length-1])
        
        #### reinitialize to the parameters ####
        if end_row == 0: 
            end_row = row_length - 1
        if end_column == 0:
            end_column = column_length - 1
        ########################################

        for (i_row, real) in enumerate(matrix):
            row = matrix[i_row]
            if (i_row >= begin_row) and (i_row <= end_row): 
                cache_matrix.append(row[begin_column:end_column+1]) 

        return cache_matrix

    def paste_matrix(self):
        pass
    
    
    def update_found(self, found_max, found_row,found_column): 
        self.found_max = found_max
        self.found_row = found_row 
        self.found_column = found_column
        
    def obtain_max(self, matrix):    
        self.found_max = None
        self.found_row = None 
        self.found_column = None

        for (i_row, row) in enumerate(matrix):
            
            if i_row == 0 or self.found_max == None: 
                
                self.update_found(max(row), i_row, row.index(max(row)))
                continue 
                       
            elif max(row) > self.found_max: 
                self.update_found(max(row), i_row, row.index(max(row)))    

    def h_pivot_normalize(self, begin_row = 0, begin_column = 0): 
        array = self.matrix_A[begin_row][begin_column:]
        for (i_column, column) in enumerate(array):
            self.matrix_A[begin_row][i_column + begin_column] = column/array[0]


    def v_pivot_zero(self, begin_row = 0): 
        pass


gauss = Gauss()
gauss.set_A(A)
gauss.obtain_max(A)
gauss.swap_row(0, gauss.found_row)
gauss.swap_column(0, gauss.found_column)

gauss.h_pivot_normalize(1, 1)


# call it a day, thank u for watching XD.
# Out:
# [[1.0, 0.0, 1.5, 2.0], [4, 3, 8, 9], [7, 4, 1, 3], [5, 1, 1, 5]]
